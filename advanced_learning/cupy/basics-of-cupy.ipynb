# %% [markdown]
# ## Basics of cupy.ndarray
#
# CuPy is a GPU array backend that implements a subset of NumPy interface. In the following code, cp is an abbreviation of cupy, following the standard convention of abbreviating numpy as np:

# %%
import numpy as np
import cupy as cp

# %%
x_gpu = cp.array([1, 2, 3])
x_cpu = cp.asnumpy(x_gpu)

# %%
l2_cpu = np.linalg.norm(x_cpu)
l2_gpu = cp.linalg.norm(x_gpu)

print("l2 (CPU) =", l2_cpu)
print("l2 (GPU) =", l2_gpu)
# Out:
# l2 (CPU) = 3.7416573867739413
# l2 (GPU) = 3.7416573867739413

# %%
cp.cuda.Device(2)
# Out:
# <CUDA Device 2>

# %%
x_gpu = cp.array([1, 2, 3])
l2_gpu = cp.linalg.norm(x_gpu)

# %%
x_on_gpu0 = cp.array([1, 2, 3, 4, 5])

# %%
with cp.cuda.Device(1):
   x_on_gpu1 = cp.array([1, 2, 3, 4, 5])
x_on_gpu0 = cp.array([1, 2, 3, 4, 5])

# %% [markdown]
# ### Move arrays to device

# %% [markdown]
# x_cpu =
